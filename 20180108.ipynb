# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc" style="margin-top: 1em;"><ul class="toc-item"><li><span><a href="#数据准备与数据清洗" data-toc-modified-id="数据准备与数据清洗-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>数据准备与数据清洗</a></span><ul class="toc-item"><li><span><a href="#数据描述" data-toc-modified-id="数据描述-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>数据描述</a></span></li><li><span><a href="#机器和Cache组对应关系" data-toc-modified-id="机器和Cache组对应关系-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>机器和Cache组对应关系</a></span></li><li><span><a href="#有效数据描述" data-toc-modified-id="有效数据描述-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>有效数据描述</a></span><ul class="toc-item"><li><span><a href="#cahce组内机器数据缺失" data-toc-modified-id="cahce组内机器数据缺失-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>cahce组内机器数据缺失</a></span></li><li><span><a href="#达标率数据缺失" data-toc-modified-id="达标率数据缺失-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>达标率数据缺失</a></span></li></ul></li></ul></li><li><span><a href="#读取数据" data-toc-modified-id="读取数据-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>读取数据</a></span><ul class="toc-item"><li><span><a href="#数据文件夹描述" data-toc-modified-id="数据文件夹描述-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>数据文件夹描述</a></span></li></ul></li><li><span><a href="#特征工程" data-toc-modified-id="特征工程-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>特征工程</a></span><ul class="toc-item"><li><span><a href="#单机聚合" data-toc-modified-id="单机聚合-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>单机聚合</a></span><ul class="toc-item"><li><span><a href="#聚合CPU" data-toc-modified-id="聚合CPU-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>聚合CPU</a></span><ul class="toc-item"><li><span><a href="#cpu_related" data-toc-modified-id="cpu_related-3.1.1.1"><span class="toc-item-num">3.1.1.1&nbsp;&nbsp;</span>cpu_related</a></span></li><li><span><a href="#聚合" data-toc-modified-id="聚合-3.1.1.2"><span class="toc-item-num">3.1.1.2&nbsp;&nbsp;</span>聚合</a></span></li></ul></li><li><span><a href="#聚合disk" data-toc-modified-id="聚合disk-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>聚合disk</a></span><ul class="toc-item"><li><span><a href="#disk_related" data-toc-modified-id="disk_related-3.1.2.1"><span class="toc-item-num">3.1.2.1&nbsp;&nbsp;</span>disk_related</a></span></li><li><span><a href="#disk_available_sd_related" data-toc-modified-id="disk_available_sd_related-3.1.2.2"><span class="toc-item-num">3.1.2.2&nbsp;&nbsp;</span>disk_available_sd_related</a></span></li><li><span><a href="#disk_used_sd_related" data-toc-modified-id="disk_used_sd_related-3.1.2.3"><span class="toc-item-num">3.1.2.3&nbsp;&nbsp;</span>disk_used_sd_related</a></span></li><li><span><a href="#聚合" data-toc-modified-id="聚合-3.1.2.4"><span class="toc-item-num">3.1.2.4&nbsp;&nbsp;</span>聚合</a></span></li></ul></li><li><span><a href="#聚合flowperproc" data-toc-modified-id="聚合flowperproc-3.1.3"><span class="toc-item-num">3.1.3&nbsp;&nbsp;</span>聚合flowperproc</a></span><ul class="toc-item"><li><span><a href="#flowperproc_related" data-toc-modified-id="flowperproc_related-3.1.3.1"><span class="toc-item-num">3.1.3.1&nbsp;&nbsp;</span>flowperproc_related</a></span></li><li><span><a href="#聚合" data-toc-modified-id="聚合-3.1.3.2"><span class="toc-item-num">3.1.3.2&nbsp;&nbsp;</span>聚合</a></span></li></ul></li><li><span><a href="#hitratio聚合" data-toc-modified-id="hitratio聚合-3.1.4"><span class="toc-item-num">3.1.4&nbsp;&nbsp;</span>hitratio聚合</a></span><ul class="toc-item"><li><span><a href="#hitratio_related" data-toc-modified-id="hitratio_related-3.1.4.1"><span class="toc-item-num">3.1.4.1&nbsp;&nbsp;</span>hitratio_related</a></span></li><li><span><a href="#聚合" data-toc-modified-id="聚合-3.1.4.2"><span class="toc-item-num">3.1.4.2&nbsp;&nbsp;</span>聚合</a></span></li></ul></li><li><span><a href="#聚合inouttraffic" data-toc-modified-id="聚合inouttraffic-3.1.5"><span class="toc-item-num">3.1.5&nbsp;&nbsp;</span>聚合inouttraffic</a></span><ul class="toc-item"><li><span><a href="#inouttraffic_related" data-toc-modified-id="inouttraffic_related-3.1.5.1"><span class="toc-item-num">3.1.5.1&nbsp;&nbsp;</span>inouttraffic_related</a></span></li><li><span><a href="#聚合" data-toc-modified-id="聚合-3.1.5.2"><span class="toc-item-num">3.1.5.2&nbsp;&nbsp;</span>聚合</a></span></li></ul></li><li><span><a href="#聚合ioutil" data-toc-modified-id="聚合ioutil-3.1.6"><span class="toc-item-num">3.1.6&nbsp;&nbsp;</span>聚合ioutil</a></span><ul class="toc-item"><li><span><a href="#疑问：数据全空" data-toc-modified-id="疑问：数据全空-3.1.6.1"><span class="toc-item-num">3.1.6.1&nbsp;&nbsp;</span>疑问：数据全空</a></span></li><li><span><a href="#聚合" data-toc-modified-id="聚合-3.1.6.2"><span class="toc-item-num">3.1.6.2&nbsp;&nbsp;</span>聚合</a></span></li></ul></li><li><span><a href="#聚合resptime" data-toc-modified-id="聚合resptime-3.1.7"><span class="toc-item-num">3.1.7&nbsp;&nbsp;</span>聚合resptime</a></span><ul class="toc-item"><li><span><a href="#聚合" data-toc-modified-id="聚合-3.1.7.1"><span class="toc-item-num">3.1.7.1&nbsp;&nbsp;</span>聚合</a></span></li></ul></li><li><span><a href="#聚合storeentries" data-toc-modified-id="聚合storeentries-3.1.8"><span class="toc-item-num">3.1.8&nbsp;&nbsp;</span>聚合storeentries</a></span><ul class="toc-item"><li><span><a href="#聚合storeentries_related" data-toc-modified-id="聚合storeentries_related-3.1.8.1"><span class="toc-item-num">3.1.8.1&nbsp;&nbsp;</span>聚合storeentries_related</a></span></li><li><span><a href="#聚合" data-toc-modified-id="聚合-3.1.8.2"><span class="toc-item-num">3.1.8.2&nbsp;&nbsp;</span>聚合</a></span></li></ul></li><li><span><a href="#聚合mem" data-toc-modified-id="聚合mem-3.1.9"><span class="toc-item-num">3.1.9&nbsp;&nbsp;</span>聚合mem</a></span><ul class="toc-item"><li><span><a href="#mem_related" data-toc-modified-id="mem_related-3.1.9.1"><span class="toc-item-num">3.1.9.1&nbsp;&nbsp;</span>mem_related</a></span></li><li><span><a href="#聚合" data-toc-modified-id="聚合-3.1.9.2"><span class="toc-item-num">3.1.9.2&nbsp;&nbsp;</span>聚合</a></span></li></ul></li><li><span><a href="#聚合ipredi" data-toc-modified-id="聚合ipredi-3.1.10"><span class="toc-item-num">3.1.10&nbsp;&nbsp;</span>聚合ipredi</a></span><ul class="toc-item"><li><span><a href="#ipredi_related" data-toc-modified-id="ipredi_related-3.1.10.1"><span class="toc-item-num">3.1.10.1&nbsp;&nbsp;</span>ipredi_related</a></span></li><li><span><a href="#聚合" data-toc-modified-id="聚合-3.1.10.2"><span class="toc-item-num">3.1.10.2&nbsp;&nbsp;</span>聚合</a></span></li></ul></li><li><span><a href="#单机聚合总结" data-toc-modified-id="单机聚合总结-3.1.11"><span class="toc-item-num">3.1.11&nbsp;&nbsp;</span>单机聚合总结</a></span></li><li><span><a href="#单机聚合并和达标率进行比对" data-toc-modified-id="单机聚合并和达标率进行比对-3.1.12"><span class="toc-item-num">3.1.12&nbsp;&nbsp;</span>单机聚合并和达标率进行比对</a></span><ul class="toc-item"><li><span><a href="#达标率和IOUTIL" data-toc-modified-id="达标率和IOUTIL-3.1.12.1"><span class="toc-item-num">3.1.12.1&nbsp;&nbsp;</span>达标率和IOUTIL</a></span></li><li><span><a href="#达标率和CPU" data-toc-modified-id="达标率和CPU-3.1.12.2"><span class="toc-item-num">3.1.12.2&nbsp;&nbsp;</span>达标率和CPU</a></span></li><li><span><a href="#达标率和channeltraffic.in" data-toc-modified-id="达标率和channeltraffic.in-3.1.12.3"><span class="toc-item-num">3.1.12.3&nbsp;&nbsp;</span>达标率和channeltraffic.in</a></span></li><li><span><a href="#达标率和channeltraffic.out" data-toc-modified-id="达标率和channeltraffic.out-3.1.12.4"><span class="toc-item-num">3.1.12.4&nbsp;&nbsp;</span>达标率和channeltraffic.out</a></span></li><li><span><a href="#达标率和mem.used" data-toc-modified-id="达标率和mem.used-3.1.12.5"><span class="toc-item-num">3.1.12.5&nbsp;&nbsp;</span>达标率和mem.used</a></span></li><li><span><a href="#达标率和mem.cached" data-toc-modified-id="达标率和mem.cached-3.1.12.6"><span class="toc-item-num">3.1.12.6&nbsp;&nbsp;</span>达标率和mem.cached</a></span></li><li><span><a href="#达标率和ipredi" data-toc-modified-id="达标率和ipredi-3.1.12.7"><span class="toc-item-num">3.1.12.7&nbsp;&nbsp;</span>达标率和ipredi</a></span></li><li><span><a href="#疑问" data-toc-modified-id="疑问-3.1.12.8"><span class="toc-item-num">3.1.12.8&nbsp;&nbsp;</span>疑问</a></span></li></ul></li><li><span><a href="#单机聚合&amp;达标率对照图" data-toc-modified-id="单机聚合&amp;达标率对照图-3.1.13"><span class="toc-item-num">3.1.13&nbsp;&nbsp;</span>单机聚合&amp;达标率对照图</a></span></li></ul></li><li><span><a href="#多机聚合" data-toc-modified-id="多机聚合-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>多机聚合</a></span></li><li><span><a href="#缺失值与|标准化" data-toc-modified-id="缺失值与|标准化-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>缺失值与|标准化</a></span></li></ul></li><li><span><a href="#模型与训练" data-toc-modified-id="模型与训练-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>模型与训练</a></span><ul class="toc-item"><li><span><a href="#依赖库" data-toc-modified-id="依赖库-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>依赖库</a></span></li><li><span><a href="#准备mini-batches" data-toc-modified-id="准备mini-batches-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>准备mini-batches</a></span></li><li><span><a href="#训练集与测试集划分" data-toc-modified-id="训练集与测试集划分-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>训练集与测试集划分</a></span></li><li><span><a href="#lstm模型" data-toc-modified-id="lstm模型-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>lstm模型</a></span><ul class="toc-item"><li><span><a href="#输入" data-toc-modified-id="输入-4.4.1"><span class="toc-item-num">4.4.1&nbsp;&nbsp;</span>输入</a></span></li><li><span><a href="#建立lstm" data-toc-modified-id="建立lstm-4.4.2"><span class="toc-item-num">4.4.2&nbsp;&nbsp;</span>建立lstm</a></span></li><li><span><a href="#建立输出" data-toc-modified-id="建立输出-4.4.3"><span class="toc-item-num">4.4.3&nbsp;&nbsp;</span>建立输出</a></span></li><li><span><a href="#损失函数" data-toc-modified-id="损失函数-4.4.4"><span class="toc-item-num">4.4.4&nbsp;&nbsp;</span>损失函数</a></span></li><li><span><a href="#优化器" data-toc-modified-id="优化器-4.4.5"><span class="toc-item-num">4.4.5&nbsp;&nbsp;</span>优化器</a></span></li><li><span><a href="#RNN" data-toc-modified-id="RNN-4.4.6"><span class="toc-item-num">4.4.6&nbsp;&nbsp;</span>RNN</a></span></li></ul></li><li><span><a href="#超参数" data-toc-modified-id="超参数-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>超参数</a></span></li><li><span><a href="#建立模型" data-toc-modified-id="建立模型-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>建立模型</a></span></li><li><span><a href="#开始训练" data-toc-modified-id="开始训练-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>开始训练</a></span></li><li><span><a href="#训练损失曲线" data-toc-modified-id="训练损失曲线-4.8"><span class="toc-item-num">4.8&nbsp;&nbsp;</span>训练损失曲线</a></span></li><li><span><a href="#模型验证" data-toc-modified-id="模型验证-4.9"><span class="toc-item-num">4.9&nbsp;&nbsp;</span>模型验证</a></span></li></ul></li></ul></div>

# %%
import pandas as pd
import numpy as np
import os
from sklearn.decomposition import PCA
from sklearn import preprocessing
import time
import matplotlib.pyplot as plt
import matplotlib as mpl
from datetime import datetime, timedelta
from tzlocal import get_localzone
# %matplotlib inline

# %% [markdown]
# # 数据准备与数据清洗

# %% [markdown]
# ## 数据描述

# %% [markdown]
# 对已有的数据进行描述,cache组列表、cache组对应ip数量的情况

# %%
cache_group_ipmd5=pd.read_csv("machine_pptv_fudan.csv")
cache_group_ipmd5['ip_num']=1
cache_ip_num=cache_group_ipmd5['ip_num'].groupby(cache_group_ipmd5['cache_group_id']).sum()
print("cache_group数量： ", len(cache_ip_num))
# Out:
# cache_group数量：  472

# %%
cache_ip_num=cache_ip_num.sort_values(ascending=False)   #cache_group按照拥有的ip个数从大到小排列
cache_ip_num
# Out:
# cache_group_id
# 108650                 28
# 60074                  26
# 92595                  25
# 77794                  25
# 82569                  24
# 82570                  24
# 30716                  24
# 1163500162396255604    21
# 30718                  20
# 56262                  20
# 83198                  19
# 84729                  18
# 61411                  17
# 99326                  17
# 1168003737385630739    17
# 40807                  17
# 25842                  17
# 61591                  16
# 12553                  16
# 1163511997730737034    16
# 50688                  15
# 110561                 15
# 60904                  15
# 1168000483617417887    14
# 94484                  14
# 87303                  14
# 91051                  14
# 30717                  14
# 54802                  14
# 61409                  14
#                        ..
# 1163501857126669486     1
# 1172514479674519739     1
# 103242                  1
# 1163502200068856147     1
# ...

# %% [markdown]
# ## 机器和Cache组对应关系

# %% [markdown]
# 描述以下数据缺失的情况

# %% [markdown]
# ## 有效数据描述

# %% [markdown]
# ### cahce组内机器数据缺失

# %% [markdown]
# cache组内机器数据缺失值的情况，指的是部分cache组内，机器的machine数据只有时间戳一列，没有有效的机器数据

# %%
file_dir="./machine/pptv_pstatp_20180107/"  #以28号的数据来说明
cache_ip_num_pure=cache_ip_num.copy()

# %%
count=0
flag=False
skip=False
machine_miss_cache_group_list=[]    #machine数据缺失的cache组列表
machine_complete_cache_group_list=[]#machine数据不缺失的cache组列表
for cache_group_selected in cache_ip_num.index:
    cache_group_selected_ip_list=list(cache_group_ipmd5[cache_group_ipmd5['cache_group_id']==cache_group_selected]['server_ip_md5'])
    for st in  cache_group_selected_ip_list:
        dir_=file_dir+st+".csv"
        if os.path.exists(dir_)==False:
            skip=True
            break
        if(pd.read_csv(dir_).shape[1]<90):    #阈值条件
            count=count+1
            flag=True
    if skip==True:
        skip=False
        continue
    cache_ip_num_pure[cache_group_selected]=cache_ip_num_pure[cache_group_selected]-count
    count=0
    if(flag==True):
        machine_miss_cache_group_list.append(cache_group_selected)
    else:
        machine_complete_cache_group_list.append(cache_group_selected)
    flag=False

# %%
print("机器数据不缺失的cache组数量： ",len(machine_complete_cache_group_list))
# Out:
# 机器数据不缺失的cache组数量：  251

# %% [markdown]
# 机器数据没有缺失的cache组按照ip个数排列

# %%
cache_ip_num[machine_complete_cache_group_list]
# Out:
# cache_group_id
# 109918                 11
# 109912                 11
# 86210                   9
# 61911                   9
# 106004                  9
# 63608                   9
# 63307                   9
# 105635                  9
# 21494                   9
# 48986                   9
# 72908                   8
# 84571                   8
# 68712                   8
# 79727                   8
# 73351                   7
# 42509                   7
# 38804                   7
# 32926                   7
# 1163499408573062454     7
# 30884                   7
# 55356                   7
# 1168001298756450720     7
# 85813                   7
# 105713                  6
# 86251                   6
# 108275                  6
# 105739                  6
# 92493                   6
# 85111                   6
# 94163                   6
#                        ..
# 106369                  2
# 104652                  2
# 105762                  2
# 1168006197526214097     2
# ...

# %% [markdown]
# ### 达标率数据缺失

# %% [markdown]
# 达标率缺失是指，对应cache的达标率数据缺失很多记录（每分钟采样一次），缺失过多没有办法有效补充

# %%
hit_rate=pd.read_csv("./rate/2018-01-07_vc.log")  #以28号数据为例
hit_rate_dict=dict(list(hit_rate.groupby(['cache_group_ID'])))
# Out:
# d:\program files\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2717: DtypeWarning: Columns (2,7,9,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
len(hit_rate_dict)  #达标率的cache_group个数跟之前对照表的cache_group数量不一样
# Out:
# 1145

# %%
num=0
evaluable_cache_group_list={}
for i in machine_complete_cache_group_list:
    if str(i) in hit_rate_dict:
        num+=1
        hit_rate_df_0=hit_rate_dict[i]
        hit_rate_df_1=hit_rate_dict[str(i)]
        hit_rate_df=pd.concat([hit_rate_df_0,hit_rate_df_1]).sort_values("time")
       
        #print(hit_rate_df.shape[0])
        if hit_rate_df.shape[0]>1350:   #原始数据项太少
            #print(i)
            hit_rate_df=hit_rate_df.loc[hit_rate_df['hit_reach_rate']!='-',:]
            hit_rate_df['hit_reach_cnt']=0
            hit_rate_df[['hit_reach_rate','hit_reach_cnt','hit_cnt']]=hit_rate_df[['hit_reach_rate','hit_reach_cnt','hit_cnt']].apply(pd.to_numeric)
            hit_rate_df['hit_reach_cnt']=hit_rate_df['hit_reach_rate']*hit_rate_df['hit_cnt']/100
            hit_rate_df_1=hit_rate_df[['time','hit_reach_rate','hit_cnt','hit_reach_cnt']]
            hit_rate_df_1.reset_index()
            hit_rate_df_1[['hit_cnt','hit_reach_cnt']]=hit_rate_df[['hit_cnt','hit_reach_cnt']].apply(pd.to_numeric)
            hit_rate_df_2=hit_rate_df_1.groupby('time',as_index=False).sum()
            #hit_rate_df_2['hit_reach_rate']=hit_rate_df_2['hit_reach_cnt']/hit_rate_df_2['hit_cnt']*100
            #print(i, hit_rate_df_2.shape)
            if hit_rate_df_2.shape[0]>1300:
                evaluable_cache_group_list[i]=hit_rate_df_2.shape[0]
# Out:
# d:\program files\anaconda3\lib\site-packages\pandas\core\frame.py:2352: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[k1] = value[k2]

# %% [markdown]
# 达标率数据不缺失的cache组个数：  45
#
# 机器数据、达标率数据都不缺失的cache按照ip个数从大到小排列

# %%
print("达标率数据不缺失的cache组个数： ",len(evaluable_cache_group_list))
# Out:
# 达标率数据不缺失的cache组个数：  187

# %%
evaluable_cache_group=cache_ip_num[list(evaluable_cache_group_list.keys())].sort_values(ascending=False)

# %%
evaluable_cache_group
# Out:
# cache_group_id
# 63307                  9
# 21494                  9
# 48986                  9
# 86210                  9
# 79727                  8
# 84571                  8
# 68712                  8
# 42509                  7
# 1163499408573062454    7
# 73351                  7
# 32926                  7
# 85813                  7
# 83346                  6
# 92493                  6
# 108275                 6
# 102742                 6
# 77660                  6
# 1163501224773253317    6
# 105713                 6
# 48848                  6
# 1163501225085732910    6
# 104812                 6
# 1168015688125666574    6
# 110032                 6
# 105739                 6
# 1163508548334580718    6
# 86251                  6
# 53933                  6
# 36389                  6
# 1172506800971323423    6
#                       ..
# 15096893984740081      2
# 104737                 2
# 50250                  2
# 29239                  2
# 101657                 2
# ...

# %% [markdown]
# # 读取数据

# %% [markdown]
# ## 数据文件夹描述

# %% [raw]
# └── train_data
#     └── cacheid
#         ├── machine
#         │   ├── 2017-12-28
#         │   │   ├── ip1.csv
#         │   │   └── ip2.csv
#         │   ├── 2017-12-29
#         │   │   ├── ip1.csv
#         │   │   └── ip2.csv
#         └── rate
#             ├── 2017-12-28.csv
#             ├── 2017-12-29.csv

# %% [raw]
# rate文件格式修改：
# 去掉第一列

# %%
file_dir = "train_data"
cache_id_list = list(os.listdir(file_dir))
cache_id_list
# Out:
# ['86653',
#  '77680',
#  '105628',
#  '53431',
#  '109940',
#  '109771',
#  '11292',
#  '103721',
#  '83077',
#  '94161',
#  '72010',
#  '86794',
#  '93709',
#  '73843',
#  '92317',
#  '88170']

# %%
cache_id_selected = cache_id_list[3]
#cache_id_selected = "53914"

# %%
file_dir + '/' + cache_id_selected
# Out:
# 'train_data/53431'

# %%
machine_date_dir = file_dir + '/' + cache_id_selected + "/machine"
machine_date_list = list(os.listdir(machine_date_dir))
machine_date_list.sort()
machine_date_list
# Out:
# ['2018-01-07',
#  '2018-01-08',
#  '2018-01-09',
#  '2018-01-10',
#  '2018-01-11',
#  '2018-01-12',
#  '2018-01-13',
#  '2018-01-14',
#  '2018-01-15',
#  '2018-01-16',
#  '2018-01-17',
#  '2018-01-18',
#  '2018-01-19',
#  '2018-01-20',
#  '2018-01-21',
#  '2018-01-22']

# %%
rate_date_dir = file_dir + '/' + cache_id_selected + "/rate"
rate_list = list(os.listdir(rate_date_dir))

# %%
rate_list
# Out:
# ['2018-01-18.csv',
#  '2018-01-22.csv',
#  '2018-01-07.csv',
#  '2018-01-11.csv',
#  '2018-01-14.csv',
#  '2018-01-19.csv',
#  '2018-01-20.csv',
#  '2018-01-15.csv',
#  '2018-01-08.csv',
#  '2018-01-10.csv',
#  '2018-01-16.csv',
#  '2018-01-09.csv',
#  '2018-01-13.csv',
#  '2018-01-21.csv',
#  '2018-01-12.csv',
#  '2018-01-17.csv']

# %%
ip_dir = machine_date_dir + '/' + machine_date_list[0]
ip_list = os.listdir(ip_dir)
for i, _ in enumerate(ip_list):
    ip_list[i] = ip_list[i][0:-4]

# %%
ip_list
# Out:
# ['063b0818de09d9a98e53d0280e9b2aaf',
#  '925c8de169182e8fc17120fbf3f00541',
#  'ec6bf099dd231935b51dea7a9c57c0f7',
#  '9a8e6370ec84d0c6abc6a5dcfd71987f']

# %%
d = {}

# %%
rate_list = []
for date in machine_date_list:
    temp = rate_date_dir + '/' + date + '.csv'
    temp = pd.read_csv(temp)
    rate_list.append(temp)

rate_pd = pd.concat(rate_list, ignore_index=True)
rate_pd["hit_reach_rate"]=rate_pd["hit_reach_rate"]/100

# %%
rate_pd.plot(x='time', y="hit_reach_rate", figsize=(200, 5))

# %%
d = {}
for ip in ip_list:
    machine_data_list=[]
    for date in machine_date_list:
        temp = machine_date_dir + '/' + date + '/' + ip + '.csv'
        temp = pd.read_csv(temp)
        machine_data_list.append(temp)
    d[ip] = pd.concat(machine_data_list, ignore_index=True)

# %%
d[ip]
# Out:
#              time  channeltraffic.in  channeltraffic.out  cpu.usage.cpu0  \
# 0      1515254400       8.930988e+09        9.594709e+09          71.917
# 1      1515254460       9.620151e+09        1.026063e+10          74.960
# 2      1515254520       1.042361e+10        1.114107e+10          76.031
# 3      1515254580       1.052479e+10        1.117366e+10          76.833
# 4      1515254640       1.087818e+10        1.155001e+10          71.979
# 5      1515254700       1.038714e+10        1.109758e+10          75.469
# 6      1515254760       1.042078e+10        1.118693e+10          77.659
# 7      1515254820       1.011855e+10        1.073364e+10          74.913
# 8      1515254880       1.029078e+10        1.092248e+10          76.241
# 9      1515254940       1.053030e+10        1.141149e+10          75.569
# 10     1515255000       1.067371e+10        1.140438e+10          77.911
# 11     1515255060       1.169442e+10        1.241439e+10          77.690
# ...

# %%
check_date='2018-01-21'
temp = rate_date_dir + '/' + check_date + '.csv'
temp_rate_pd = pd.read_csv(temp)
temp_rate_pd["hit_reach_rate"]=temp_rate_pd["hit_reach_rate"]/100
temp_rate_pd.plot(x='time', y="hit_reach_rate", figsize=(40, 5),yticks=[0,1] )

# %%
temp_rate_pd.describe()
# Out:
#         Unnamed: 0  hit_reach_rate      hit_cnt
# count  1440.000000     1440.000000  1440.000000
# mean    719.500000        0.884745  3628.564583
# std     415.836506        0.019609  1256.610264
# min       0.000000        0.767992  1931.000000
# 25%     359.750000        0.876439  2600.000000
# 50%     719.500000        0.886867  3370.500000
# 75%    1079.250000        0.896734  4182.500000
# max    1439.000000        0.932059  8137.000000

# %%
d = {}
for ip in ip_list:
    temp = machine_date_dir + '/' + check_date + '/' + ip + '.csv'
    temp = pd.read_csv(temp)
    d[ip] = temp
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-570a34b491f8> in <module>()
#       1 d = {}
#       2 for ip in ip_list:
# ----> 3     temp = machine_date_dir + '/' + check_date + '/' + ip + '.csv'
#       4     temp = pd.read_csv(temp)
#       5     d[ip] = temp
#
# NameError: name 'check_date' is not defined

# %%
rate_date_dir
# Out:
# 'train_data/73843/rate'

# %% [markdown]
# # 特征工程

# %% [markdown]
# ## 单机聚合

# %%
machine0 = d[ip_list[0]]
machine1 = d[ip_list[1]]
machine2 = d[ip_list[2]]
machine3 = d[ip_list[3]]

# %%
machine0.shape
# Out:
# (23040, 138)

# %%
machine

# %%
feature_list = list(machine.columns)

# %%
feature_list

# %%
def get_related(machine, string):
    feature_list = list(machine.columns)
    return [i for i in feature_list if i[0:len(string)] == string]

# %%
def sum_columns(data, col_list):
    return data[col_list].apply(np.sum, axis=1)

# %% [markdown]
# ### 聚合CPU

# %% [markdown]
# #### cpu_related

# %%
cpu_related = get_related(machine, 'cpu')

# %%
cpu_related

# %%
machine[cpu_related]

# %% [markdown]
# #### 聚合

# %%
cpu = machine1[cpu_related].apply(np.sum, axis=1) / len(cpu_related)

# %%
machine1_aggregated = machine1.drop(cpu_related, axis=1)

# %%
machine1_aggregated['cpu'] = cpu

# %%
machine1_aggregated

# %% [markdown]
# ### 聚合disk

# %% [markdown]
# #### disk_related

# %%
disk_related = [i for i in feature_list if i[0:4] == "disk"]

# %%
disk_related

# %%
machine1[disk_related]

# %% [markdown]
# #### disk_available_sd_related

# %%
disk_available_sd_related = [
    i for i in feature_list
    if i[0:len("disk.available.sd")] == "disk.available.sd"
]

# %% [markdown]
# #### disk_used_sd_related

# %%
disk_used_sd_related = [
    i for i in feature_list if i[0:len("disk.used.sd")] == "disk.used.sd"
]

# %%
machine1[disk_related].iloc[0]

# %%
disk_flowcollect = machine1[[
    'disk.available.flowcollect', 'disk.used.flowcollect'
]].apply(
    np.sum, axis=1)

# %%
disk_sda3 = machine1[['disk.available.sda3', 'disk.used.sda3']].apply(
    np.sum, axis=1)

# %%
disk_sda3

# %%
machine1.plot(x='time', y='disk.available.sda3')

# %%
machine1.plot(x='time', y='disk.available.flowcollect', style='o')

# %% [markdown]
# #### 聚合

# %% [markdown]
# disk_available_sd_related和disk_used_sd_related是线性关系，聚合时候只保留一个

# %%
disk_available_sd = machine1_aggregated[disk_available_sd_related].apply(
    np.sum, axis=1)

# %%
machine1_aggregated = machine1_aggregated.drop(disk_related, axis=1)

# %%
machine1_aggregated['disk_available_sd'] = disk_available_sd

# %%
machine1_aggregated['disk.available.flowcollect'] = machine1[
    'disk.available.flowcollect']

# %%
machine1_aggregated['disk.available.tmpfs'] = machine1['disk.available.tmpfs']

# %% [markdown]
# ### 聚合flowperproc

# %% [markdown]
# #### flowperproc_related

# %%
flowperproc_related = [
    i for i in feature_list if i[0:len("flowperproc")] == "flowperproc"
]

# %%
flowperproc_related

# %%
machine1[flowperproc_related]

# %% [markdown]
# #### 聚合

# %%
machine1_aggregated = machine1_aggregated.drop(flowperproc_related, axis=1)

# %%
machine1_aggregated['flowperproc.allReqCnt'] = machine1[
    'flowperproc.allReqCnt']

# %% [markdown]
# ### hitratio聚合

# %% [markdown]
# #### hitratio_related

# %%
hitratio_related = [
    i for i in feature_list if i[0:len("hitratio")] == "hitratio"
]

# %%
hitratio_related

# %%
machine1[hitratio_related]

# %% [markdown]
# #### 聚合

# %%
hitratio = machine1[hitratio_related].apply(np.sum, axis=1)

# %%
machine1_aggregated = machine1_aggregated.drop(hitratio_related, axis=1)

# %%
machine1_aggregated['hitratio'] = hitratio

# %% [markdown]
# ### 聚合inouttraffic

# %% [markdown]
# #### inouttraffic_related

# %%
inouttraffic_related = get_related("inouttraffic")

# %%
inouttraffic_related

# %%
machine1[inouttraffic_related]

# %% [markdown]
# #### 聚合

# %%
def aggregate_inouttraffic(machine):
    inouttraffic_related = get_related(machine, 'inouttraffic')
    machine_aggregated = machine.drop(inouttraffic_related, axis=1)
    #inouttraffic.in.eth2 	inouttraffic.out.eth2 	inouttraffic.total.eth2c
    inouttraffic_in_index_list=[]
    inouttraffic_out_eth2_list=[]
    inouttraffic_total_eth2c_list=[]
    machine_aggregated['inouttraffic.in'] = machine[
        'flowperproc.allReqCnt']
    return machine_aggregated

# %%
m1

# %%
for i in m1.columns[]

# %% [markdown]
# ### 聚合ioutil

# %%
ioutil_related = get_related('ioutil')

# %%
ioutil_related

# %%
machine1[ioutil_related]

# %% [markdown]
# #### 疑问：数据全空

# %% [markdown]
# #### 聚合

# %%
ioutil = machine1[ioutil_related].apply(np.sum, axis=1)

# %%
machine1_aggregated = machine1_aggregated.drop(ioutil_related, axis=1)

# %%
machine1_aggregated['ioutil'] = ioutil

# %% [markdown]
# ### 聚合resptime

# %%
resptime_related = get_related('resptime')

# %%
resptime_related

# %%
machine1[resptime_related]

# %% [markdown]
# #### 聚合

# %%
machine1_aggregated = machine1_aggregated.drop(resptime_related, axis=1)

# %% [markdown]
# ### 聚合storeentries

# %% [markdown]
# #### 聚合storeentries_related

# %%
storeentries_related = get_related('storeentries')

# %%
storeentries_related

# %%
machine1[storeentries_related]

# %% [markdown]
# #### 聚合

# %%
storeentries_allStoreECnt = machine1['storeentries.allStoreECnt']

# %%
machine1_aggregated = machine1_aggregated.drop(storeentries_related, axis=1)
machine1_aggregated['storeentries_allStoreECnt'] = storeentries_allStoreECnt

# %% [markdown]
# ### 聚合mem

# %% [markdown]
# #### mem_related

# %%
mem_related = get_related('mem')

# %%
mem_related

# %%
mem_drop_column = []

# %%
machine1[mem_related]

# %%
machine1["mem.swapusage"].describe()
mem_drop_column.append("mem.swapusage")

# %%
machine1['mem.shared'].describe()
mem_drop_column.append("mem.shared")

# %%
sum_columns(machine1, ["mem.used", "mem.free"])
mem_drop_column.append("mem.free")

# %%
mem_drop_column.append("mem.total")

# %%
sum_columns(machine1, ["mem.buffers_cache_free", "mem.buffers_cache_used"])
mem_drop_column.append("mem.buffers_cache_free")

# %%
mem_drop_column

# %% [markdown]
# #### 聚合

# %%
machine1_aggregated = machine1_aggregated.drop(mem_drop_column, axis=1)

# %% [markdown]
# ### 聚合ipredi

# %% [markdown]
# #### ipredi_related

# %%
ipredi_related = get_related('ipredi')

# %%
ipredi_related

# %%
machine1[ipredi_related]

# %% [markdown]
# #### 聚合

# %% [markdown]
# 全为零的属性

# %%
ipredi_drop_column = []
ipredi_drop_column.append("ipredi.errflow")
ipredi_drop_column.append("ipredi.overflow")
ipredi_drop_column.append("ipredi.redflow")

# %% [markdown]
# ### 单机聚合总结

# %%
def get_related(machine, string):
    feature_list = list(machine.columns)
    return [i for i in feature_list if i[0:len(string)] == string]

# %%
def sum_columns(data, col_list):
    return data[col_list].apply(np.sum, axis=1)

# %%
def aggregate_cpu(machine):
    cpu_related = get_related(machine, 'cpu')
    num=len(cpu_related)
    cpu = sum_columns(machine, cpu_related)
    
    machine_aggregated = machine.drop(cpu_related, axis=1)
    machine_aggregated['cpu'] = cpu/num
    return machine_aggregated

# %%
def aggregate_disk(machine):
    disk_related = get_related(machine, 'disk')
    disk_available_sd_related = get_related(machine, 'disk.available.sd')
    disk_available_sd = sum_columns(machine, disk_available_sd_related)
    machine_aggregated = machine.drop(disk_related, axis=1)
    machine_aggregated['disk_available_sd'] = disk_available_sd
    machine_aggregated['disk.available.flowcollect'] = machine[
        'disk.available.flowcollect']
    machine_aggregated['disk.available.tmpfs'] = machine[
        'disk.available.tmpfs']
    return machine_aggregated

# %%
def aggregate_flowperproc(machine):
    flowperproc_related = get_related(machine, 'flowperproc')
    machine_aggregated = machine.drop(flowperproc_related, axis=1)
    machine_aggregated['flowperproc.allReqCnt'] = machine[
        'flowperproc.allReqCnt']
    return machine_aggregated

# %%
def aggregate_hitratio(machine):
    hitratio_related = get_related(machine, 'hitratio')
    hitratio = sum_columns(machine, hitratio_related)
    machine_aggregated = machine.drop(hitratio_related, axis=1)
    machine_aggregated['hitratio'] = hitratio
    return machine_aggregated

# %%
def aggregate_ioutil(machine):
    ioutil_related = get_related(machine, 'ioutil')
    ioutil = sum_columns(machine, ioutil_related)
    machine_aggregated = machine.drop(ioutil_related, axis=1)
    machine_aggregated['ioutil'] = ioutil
    return machine_aggregated

# %%
def aggregate_resptime(machine):
    resptime_related = get_related(machine, 'resptime')
    machine_aggregated = machine.drop(resptime_related, axis=1)
    return machine_aggregated

# %%
def aggregate_storeentries(machine):
    storeentries_related = get_related(machine, 'storeentries')
    machine_aggregated = machine.drop(storeentries_related, axis=1)
    machine_aggregated['storeentries_allStoreECnt'] = machine[
        'storeentries.allStoreECnt']
    return machine_aggregated

# %%
def aggregate_mem(machine):
    mem_drop_column = []
    mem_drop_column.append("mem.swapusage")
    mem_drop_column.append("mem.shared")
    mem_drop_column.append("mem.free")
    mem_drop_column.append("mem.total")
    machine_aggregated = machine.drop(mem_drop_column, axis=1)
    return machine_aggregated

# %%
def aggregate_ipredi(machine):
    ipredi_drop_column = []
    ipredi_drop_column.append("ipredi.errflow")
    ipredi_drop_column.append("ipredi.overflow")
    ipredi_drop_column.append("ipredi.redflow")
    machine_aggregated = machine.drop(ipredi_drop_column, axis=1)
    return machine_aggregated

# %%
def aggregate_single_machine(machine):
    aggregated_machine = aggregate_cpu(machine)
    #aggregated_machine = aggregate_disk(aggregated_machine)
    #aggregated_machine = aggregate_flowperproc(aggregated_machine)
    #aggregated_machine = aggregate_hitratio(aggregated_machine)
    aggregated_machine = aggregate_ioutil(aggregated_machine)
    #aggregated_machine = aggregate_ipredi(aggregated_machine)
    aggregated_machine = aggregate_resptime(aggregated_machine)
    aggregated_machine = aggregate_mem(aggregated_machine)
    #aggregated_machine = aggregate_storeentries(aggregated_machine)
    return aggregated_machine

# %% [markdown]
# 简单的单机聚合，machine数据  aggregate_single_machine_simple

# %%
def aggregate_single_machine_simple(machine):
    machine_aggregated=pd.DataFrame()
    cpu_related = get_related(machine, 'cpu')
    num=len(cpu_related)
    cpu = sum_columns(machine, cpu_related)
    machine_aggregated['cpu'] = cpu/num
    machine_aggregated['channeltraffic.in']=machine['channeltraffic.in']
    machine_aggregated['channeltraffic.out']=machine['channeltraffic.out']
    machine_aggregated['load.total_load']=machine['load.total_load']
    return machine_aggregated

# %% [markdown]
# ### 单机聚合并和达标率进行比对

# %%
def feature_plot(df, feature_name):
    df.plot(
        x=df.index,
        y=feature_name,
        figsize=(50, 12),
        title=feature_name,
        fontsize=40,
        grid=1)

# %%
def column_plot(arr, col_num):
    plt.plot(range(len(arr[:,col_num])), arr[:,col_num])

# %%
aggregated_machine = aggregate_single_machine(machine)

# %%
aggregated_machine

# %%
aggregated_machine.columns

# %% [raw]
# for i in aggregated_machine.columns:
#     aggregated_machine.plot(x=machine1_aggregated.index,y=i,figsize=(120,12),title=i)

# %% [markdown]
# #### 达标率和IOUTIL

# %%
feature_plot(rate_pd, "hit_reach_rate")
feature_plot(aggregated_machine, "ioutil")

# %% [markdown]
# #### 达标率和CPU

# %%
feature_plot(rate_pd, "hit_reach_rate")
feature_plot(aggregated_machine, "cpu")

# %% [markdown]
# #### 达标率和channeltraffic.in

# %%
feature_plot(rate_pd, "hit_reach_rate")
feature_plot(aggregated_machine, "channeltraffic.in")

# %%
rate_pd.plot(
    x=rate_pd.index,
    y="hit_reach_rate",
    figsize=(50, 12),
    fontsize=40,
    title="hit_reach_rate",
    grid=1)
aggregated_machine.plot(
    x=aggregated_machine.index,
    y="channeltraffic.in",
    figsize=(50, 12),
    title="channeltraffic.in",
    fontsize=40,
    grid=1)

# %% [markdown]
# #### 达标率和channeltraffic.out

# %%
feature_plot(rate_pd, "hit_reach_rate")
feature_plot(aggregated_machine, "channeltraffic.out")

# %%
rate_pd.plot(
    x=rate_pd.index,
    y="hit_reach_rate",
    figsize=(50, 12),
    fontsize=40,
    title="hit_reach_rate",
    grid=1)
aggregated_machine.plot(
    x=aggregated_machine.index,
    y="channeltraffic.out",
    figsize=(50, 12),
    title="channeltraffic.out",
    fontsize=40,
    grid=1)

# %% [markdown]
# #### 达标率和mem.used

# %%
feature_plot(rate_pd, "hit_reach_rate")
feature_plot(aggregated_machine, "mem.used")

# %%
rate_pd.plot(
    x=rate_pd.index,
    y="hit_reach_rate",
    figsize=(50, 12),
    fontsize=40,
    title="hit_reach_rate",
    grid=1)
machine1_aggregated.plot(
    x=machine1_aggregated.index,
    y="mem.used",
    figsize=(50, 12),
    title="mem.used",
    fontsize=40,
    grid=1)

# %% [markdown]
# #### 达标率和mem.cached

# %%
feature_plot(rate_pd, "hit_reach_rate")
feature_plot(aggregated_machine, "mem.cached")

# %%
rate_pd.plot(
    x=rate_pd.index,
    y="hit_reach_rate",
    figsize=(50, 12),
    fontsize=40,
    title="hit_reach_rate",
    grid=1)
machine1_aggregated.plot(
    x=machine1_aggregated.index,
    y="mem.cached",
    figsize=(50, 12),
    title="mem.cached",
    fontsize=40,
    grid=1)

# %% [markdown]
# #### 达标率和ipredi

# %%
rate_pd.plot(
    x=rate_pd.index,
    y="hit_reach_rate",
    figsize=(50, 12),
    fontsize=40,
    title="hit_reach_rate",
    grid=1)
for i in ipredi_related:
    machine1_aggregated.plot(
        x=machine1_aggregated.index,
        y=i,
        figsize=(50, 12),
        title=i,
        fontsize=40,
        grid=1)

# %% [markdown]
# #### 疑问

# %% [markdown]
# 1.达标率的下降似乎和这些属性有明显的关系？
# 这个关系是本来就有的，还是和缺失值补充有关系
#
# 2.运维人员是如何同和指标的异常排查问题的？

# %% [markdown]
# ### 单机聚合&达标率对照图

# %%
aggregated_machine0 = aggregate_single_machine(machine0)
aggregated_machine1 = aggregate_single_machine(machine1)
aggregated_machine2 = aggregate_single_machine(machine2)
aggregated_machine3 = aggregate_single_machine(machine3)

# %%
img_num=9

# %%
temp_rate_pd.set_index("time", inplace=True)

# %% [markdown]
# 颜色： blue orange green red purple brown

# %%
fig=plt.figure(figsize=(30,3*6)) 

#hit_rate
ax1=fig.add_subplot(img_num,1,1)
ax1.xaxis.set_major_formatter(mdate.DateFormatter('%m-%d %H:%M'))#设置时间标签显示格式
plt.xticks(pd.date_range(temp_rate_pd.index[0],temp_rate_pd.index[-1],freq='5H'))
plt.plot(temp_rate_pd['hit_reach_rate'], linestyle='-',label="hit_reach_rate", color="blue")
plt.ylim(0,1)
plt.title('hit_reach_rate')
plt.legend()
#hit_cnt
ax1=fig.add_subplot(img_num,1,2)
ax1.xaxis.set_major_formatter(mdate.DateFormatter('%m-%d %H:%M'))#设置时间标签显示格式
plt.xticks(pd.date_range(temp_rate_pd.index[0],temp_rate_pd.index[-1],freq='5H'))
plt.plot(temp_rate_pd['hit_cnt'], linestyle='-',label="hit_cnt", color="blue")
plt.title('hit_cnt')
plt.legend()
#cpu
ax1=fig.add_subplot(img_num,1,3)
ax1.xaxis.set_major_formatter(mdate.DateFormatter('%m-%d %H:%M'))#设置时间标签显示格式
plt.xticks(pd.date_range(temp_rate_pd.index[0],temp_rate_pd.index[-1],freq='5H'))
plt.plot(aggregated_machine0['cpu'], linestyle='-',label="machine_0_cpu", color="blue")
plt.plot(aggregated_machine1['cpu'], linestyle='-',label="machine_1_cpu", color="orange")
plt.plot(aggregated_machine2['cpu'], linestyle='-',label="machine_2_cpu", color="green")
plt.plot(aggregated_machine3['cpu'], linestyle='-',label="machine_3_cpu", color="red")
plt.title('cpu_mean_usage')
plt.legend()
#mem_used/mem_cached
ax1=fig.add_subplot(img_num,1,4)
ax1.xaxis.set_major_formatter(mdate.DateFormatter('%m-%d %H:%M'))#设置时间标签显示格式
plt.xticks(pd.date_range(temp_rate_pd.index[0],temp_rate_pd.index[-1],freq='5H'))
plt.plot(aggregated_machine0['mem.used'], linestyle='-',label="machine_0_mem.used", color="blue")
plt.plot(aggregated_machine0['mem.cached'], linestyle='-',label="machine_0_mem_cached", color="orange")
plt.plot(aggregated_machine1['mem.used'], linestyle='-',label="machine_1_mem.used", color="green")
plt.plot(aggregated_machine1['mem.cached'], linestyle='-',label="machine_1_mem_cached", color="red")
plt.plot(aggregated_machine2['mem.used'], linestyle='-',label="machine_2_mem.used", color="purple")
plt.plot(aggregated_machine2['mem.cached'], linestyle='-',label="machine_2_mem_cached", color="brown")
plt.plot(aggregated_machine3['mem.used'], linestyle='-',label="machine_3_mem.used", color="pink")
plt.plot(aggregated_machine3['mem.cached'], linestyle='-',label="machine_3_mem_cached", color="yellow")
plt.title('mem_used/mem_cached')
plt.legend()
#ioutil
ax1=fig.add_subplot(img_num,1,5)
ax1.xaxis.set_major_formatter(mdate.DateFormatter('%m-%d %H:%M'))#设置时间标签显示格式
plt.xticks(pd.date_range(temp_rate_pd.index[0],temp_rate_pd.index[-1],freq='5H'))
plt.plot(aggregated_machine0['ioutil'], linestyle='-',label="machine_0_ioutil", color="blue")
plt.plot(aggregated_machine1['ioutil'], linestyle='-',label="machine_1_ioutil", color="orange")
plt.plot(aggregated_machine2['ioutil'], linestyle='-',label="machine_2_ioutil", color="green")
plt.plot(aggregated_machine3['ioutil'], linestyle='-',label="machine_3_ioutil", color="red")
plt.title('ioutil')
plt.legend()
#channel_traffic_in/out
ax1=fig.add_subplot(img_num,1,6)
ax1.xaxis.set_major_formatter(mdate.DateFormatter('%m-%d %H:%M'))#设置时间标签显示格式
plt.xticks(pd.date_range(temp_rate_pd.index[0],temp_rate_pd.index[-1],freq='5H'))
plt.plot(aggregated_machine0['channeltraffic.in'], linestyle='-',label="machine_0_channeltraffic.in", color="blue")
plt.plot(aggregated_machine0['channeltraffic.out'], linestyle='-',label="machine_0_channeltraffic.out", color="orange")
plt.plot(aggregated_machine1['channeltraffic.in'], linestyle='-',label="machine_1_channeltraffic.in", color="green")
plt.plot(aggregated_machine1['channeltraffic.out'], linestyle='-',label="machine_1_channeltraffic.out", color="red")
plt.plot(aggregated_machine2['channeltraffic.in'], linestyle='-',label="machine_2_channeltraffic.in", color="purple")
plt.plot(aggregated_machine2['channeltraffic.out'], linestyle='-',label="machine_2_channeltraffic.out", color="brown")
plt.plot(aggregated_machine3['channeltraffic.in'], linestyle='-',label="machine_3_channeltraffic.in", color="pink")
plt.plot(aggregated_machine3['channeltraffic.out'], linestyle='-',label="machine_3_channeltraffic.out", color="yellow")
plt.title('channeltraffic.in/out')
plt.legend()
#load.total_load
ax1=fig.add_subplot(img_num,1,7)
ax1.xaxis.set_major_formatter(mdate.DateFormatter('%m-%d %H:%M'))#设置时间标签显示格式
plt.xticks(pd.date_range(temp_rate_pd.index[0],temp_rate_pd.index[-1],freq='5H'))
plt.plot(aggregated_machine0['load.total_load'], linestyle='-',label="machine_0_load.total_load", color="blue")
plt.plot(aggregated_machine1['load.total_load'], linestyle='-',label="machine_1_load.total_load", color="orange")
plt.plot(aggregated_machine2['load.total_load'], linestyle='-',label="machine_2_load.total_load", color="green")
plt.plot(aggregated_machine3['load.total_load'], linestyle='-',label="machine_3_load.total_load", color="red")
plt.title('load.total_load')
plt.legend()
#tcpconn.active
ax1=fig.add_subplot(img_num,1,8)
ax1.xaxis.set_major_formatter(mdate.DateFormatter('%m-%d %H:%M'))#设置时间标签显示格式
plt.xticks(pd.date_range(temp_rate_pd.index[0],temp_rate_pd.index[-1],freq='5H'))
plt.plot(aggregated_machine0['tcpconn.active'], linestyle='-',label="machine_0_tcpconn.active", color="blue")
plt.plot(aggregated_machine1['tcpconn.active'], linestyle='-',label="machine_1_tcpconn.active", color="orange")
plt.plot(aggregated_machine2['tcpconn.active'], linestyle='-',label="machine_2_tcpconn.active", color="green")
plt.plot(aggregated_machine3['tcpconn.active'], linestyle='-',label="machine_3_tcpconn.active", color="red")
plt.title('tcpconn.active')
plt.legend()
#iowait.wait
ax1=fig.add_subplot(img_num,1,9)
ax1.xaxis.set_major_formatter(mdate.DateFormatter('%m-%d %H:%M'))#设置时间标签显示格式
plt.xticks(pd.date_range(temp_rate_pd.index[0],temp_rate_pd.index[-1],freq='5H'))
plt.plot(aggregated_machine0['iowait.wait'], linestyle='-',label="machine_0_iowait.wait", color="blue")
plt.plot(aggregated_machine1['iowait.wait'], linestyle='-',label="machine_1_iowait.wait", color="orange")
plt.plot(aggregated_machine2['iowait.wait'], linestyle='-',label="machine_2_iowait.wait", color="green")
plt.plot(aggregated_machine3['iowait.wait'], linestyle='-',label="machine_3_iowait.wait", color="red")
plt.title('iowait.wait')
plt.legend()
      
                    
plt.show()

# %% [markdown]
# ## 多机聚合

# %%
m0 = aggregate_single_machine_simple(d[ip_list[0]])

# %%
m2 = aggregate_single_machine(d[ip_list[1]])

# %%
m_3=(m1+m2)/2

# %%
m1.columns==m2.columns

# %%
m1

# %%
m2

# %%
m_3

# %%
m0
# Out:
#              cpu  channeltraffic.in  channeltraffic.out  load.total_load
# 0      56.888667       8.915614e+09        9.587898e+09             1.00
# 1      54.756167       9.006622e+09        9.656796e+09             2.34
# 2      54.526333       9.986505e+09        1.069573e+10             1.50
# 3      50.835250       9.816112e+09        1.051746e+10             0.86
# 4      52.708292       9.301693e+09        9.929057e+09             0.49
# 5      53.113833       9.509331e+09        1.017060e+10             0.58
# 6      53.967250       9.660028e+09        1.040449e+10             1.16
# 7      54.514208       1.003180e+10        1.061824e+10             0.90
# 8      54.179083       9.917694e+09        1.055397e+10             3.62
# 9      51.874833       9.772586e+09        1.041954e+10             1.43
# 10     54.065583       9.509873e+09        1.010005e+10             9.11
# 11     50.979417       9.319334e+09        9.927018e+09             3.73
# ...

# %% [markdown]
# ## 缺失值与|标准化

# %%
def prepare(x_df):
    input_df = x_df.fillna(method='pad')
    #  pad / ffill: propagate last valid observation forward to next valid
    input_df = input_df.fillna(method='backfill')
    # bfill: use NEXT valid observation to fill gap
    scaler = preprocessing.MinMaxScaler(feature_range=(-1, 1)).fit(input_df)
    input_scaled = scaler.transform(input_df)
    return input_scaled

# %%
rate_pd
# Out:
#        Unnamed: 0                 time  hit_reach_rate  hit_cnt
# 0               0  2018-01-07 00:00:00        0.964348   2974.0
# 1               1  2018-01-07 00:01:00        0.970640   3211.0
# 2               2  2018-01-07 00:02:00        0.974182   2948.0
# 3               3  2018-01-07 00:03:00        0.980877   2987.0
# 4               4  2018-01-07 00:04:00        0.981185   3148.0
# 5               5  2018-01-07 00:05:00        0.978271   3089.0
# 6               6  2018-01-07 00:06:00        0.972449   2840.0
# 7               7  2018-01-07 00:07:00        0.972894   2879.0
# 8               8  2018-01-07 00:08:00        0.978487   2801.0
# 9               9  2018-01-07 00:09:00        0.974852   2833.0
# 10             10  2018-01-07 00:10:00        0.968931   2866.0
# 11             11  2018-01-07 00:11:00        0.964422   2901.0
# 12             12  2018-01-07 00:12:00        0.978116   2697.0
# 13             13  2018-01-07 00:13:00        0.970578   2895.0
# ...

# %%
x_df=m0
#y_df=rate_pd.drop("time",axis=1).drop("Unnamed: 0",axis=1)
y_df=rate_pd['hit_reach_rate']

# %%
np_x=prepare(x_df)
np_y=prepare(y_df)
# Out:
# /home/vode/anaconda3/envs/tensorflow1.2.1/lib/python3.5/site-packages/sklearn/preprocessing/data.py:324: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)
# /home/vode/anaconda3/envs/tensorflow1.2.1/lib/python3.5/site-packages/sklearn/preprocessing/data.py:359: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   warnings.warn(DEPRECATION_MSG_1D, DeprecationWarning)

# %%
np_x.shape
# Out:
# (23040, 4)

# %%
np_y.shape
# Out:
# (23040,)

# %% [markdown]
# # 模型与训练

# %% [markdown]
# ## 依赖库

# %%
import os
import sklearn
from sklearn import preprocessing

import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.dates as mdate
import pandas as pd
import time
from datetime import datetime, timedelta
from tzlocal import get_localzone  # $ pip install tzlocal
import math
import seaborn as sns

# %matplotlib inline

# %%
from distutils.version import LooseVersion
import warnings
import tensorflow as tf

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion(
    '1.0'), 'Please use TensorFlow version 1.0 or newer'
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn(
        'No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.2.1
# Default GPU Device: /gpu:0

# %% [markdown]
# ## 准备mini-batches

# %% [markdown]
# ## 训练集与测试集划分

# %%
num = np_x.shape[0]
train_num = int(num * 0.7)
train_num = math.ceil(train_num / (60*24)) * 60 * 24 # 取整数的天
test_num = num - train_num
print("train num {}".format(train_num))
print("train num {}".format(test_num))
# Out:
# train num 17280
# train num 5760

# %%
INPUT_SIZE=np_x.shape[1] #特征维数
batch_size=100
TIME_STEP=40

# %%
INPUT_SIZE
# Out:
# 4

# %%
x_formated_list = []
y_formated_list = []
for startIdx in range(TIME_STEP):
    endIdx = startIdx + (int((train_num -startIdx)  / TIME_STEP)*TIME_STEP)

    batch_x = np_x[startIdx:endIdx].reshape(-1,TIME_STEP,INPUT_SIZE)
    batch_y = np_y[startIdx + TIME_STEP-1: endIdx : TIME_STEP].reshape(-1,1)
    x_formated_list.append(batch_x)
    y_formated_list.append(batch_y)

x_list=np.concatenate(x_formated_list)
y_list=np.concatenate(y_formated_list)

# %%
x_list.shape
# Out:
# (17241, 40, 4)

# %%
y_list.shape
# Out:
# (17241, 1)

# %%
def get_batches(x_list, y_list, batch_size=50):
    '''Create a generator that returns batches of size
       n_seqs x n_steps from arr.
       
       Arguments
       ---------
       arr: Array you want to make batches from
       n_dimensions: number of features of X
       n_seqs: Batch size, the number of sequences per batch
       n_steps: Number of sequence steps per batch
    '''
    for Idx in range(0, len(x_list) - batch_size + 1, batch_size):
        batch_x = x_list[Idx:Idx + batch_size]
        batch_y = y_list[Idx:Idx + batch_size]
        yield batch_x, batch_y

# %% [markdown]
# ## lstm模型

# %% [markdown]
# ### 输入

# %%
def build_inputs(batch_size, num_steps, input_size, output_size):
    ''' Define placeholders for inputs, targets, and dropout 
    data:image/png;base64,...
        Arguments
        ---------
        batch_size: Batch size, number of sequences per batch
        num_steps: Number of sequence steps in a batch
        
    '''
    # Declare placeholders we'll feed into the graph
    inputs = tf.placeholder(
        tf.float32, [batch_size, num_steps, input_size], name='inputs')
    targets = tf.placeholder(tf.float32, [batch_size, 1], name='targets')

    # Keep probability placeholder for drop out layers
    keep_prob = tf.placeholder(tf.float32, name='keep_prob')

    return inputs, targets, keep_prob

# %% [markdown]
# ### 建立lstm

# %%
def lstm_cell(lstm_size):
    return tf.contrib.rnn.BasicLSTMCell(lstm_size)

def build_lstm(lstm_size, num_layers, batch_size, keep_prob):
    ''' Build LSTM cell.
    
        Arguments
        ---------
        keep_prob: Scalar tensor (tf.placeholder) for the dropout keep probability
        lstm_size: Size of the hidden layers in the LSTM cells
        num_layers: Number of LSTM layers
        batch_size: Batch size

    '''
    ### Build the LSTM Cell
    # Use a basic LSTM cell
    lstm = tf.contrib.rnn.BasicLSTMCell(lstm_size)

    # Add dropout to the cell
    #drop = tf.contrib.rnn.DropoutWrapper(lstm, output_keep_prob=keep_prob)

    #Stack up multiple LSTM layers, for deep learning
    #cell = tf.contrib.rnn.MultiRNNCell([drop] * num_layers)
    #https://www.tensorflow.org/tutorials/recurrent
    stacked_lstm = tf.contrib.rnn.MultiRNNCell(
    [lstm_cell(lstm_size) for _ in range(num_layers)])
    initial_state = stacked_lstm.zero_state(batch_size, tf.float32)

    return stacked_lstm, initial_state

# %% [markdown]
# ### 建立输出

# %%
def build_output(lstm_output, in_size, output_size):
    ''' Build a softmax layer, return the softmax output and logits.
    
        Arguments
        ---------
        
        lstm_output: List of output tensors from the LSTM layer
        in_size: Size of the input tensor, for example, size of the LSTM cells
        out_size: Size of this softmax layer
    
    '''
    # 全连接层
    seq_output = tf.concat(lstm_output, axis=1)
    x = tf.reshape(seq_output, [-1, in_size])

    # Connect the RNN outputs to a softmax layer
    with tf.variable_scope('fully_conected'):
        fully_conected_w = tf.Variable(
            tf.truncated_normal((in_size, output_size), stddev=0.1))
        fully_conected_b = tf.Variable(tf.zeros(output_size))

    out = tf.matmul(x, fully_conected_w) + fully_conected_b

    return out

# %% [markdown]
# ### 损失函数

# %%
def build_loss(logits, targets):
    ''' Calculate the loss from the logits and the targets.
    
        Arguments
        ---------
    '''
    #y_reshaped = tf.reshape(targets, (batch_size,1))
    loss = tf.losses.mean_squared_error(predictions=logits, labels=targets)
    return loss

# %% [markdown]
# ### 优化器

# %%
def build_optimizer(loss, learning_rate, grad_clip):
    ''' Build optmizer for training, using gradient clipping.
    
        Arguments:
        loss: Network loss
        learning_rate: Learning rate for optimizer
    
    '''

    # Optimizer for training, using gradient clipping to control exploding gradients
    tvars = tf.trainable_variables()
    grads, _ = tf.clip_by_global_norm(tf.gradients(loss, tvars), grad_clip)
    train_op = tf.train.AdamOptimizer(learning_rate)
    optimizer = train_op.apply_gradients(zip(grads, tvars))

    return optimizer

# %% [markdown]
# ### RNN

# %%
class SL_RNN:
    def __init__(self,
                 batch_size,
                 num_steps,
                 lstm_size,
                 num_layers,
                 learning_rate,
                 input_size,
                 output_size,
                 grad_clip=5,
                 sampling=False,):

        # When we're using this network for sampling later, we'll be passing in
        # one character at a time, so providing an option for that
        tf.reset_default_graph()

        # Build the input placeholder tensors
        self.inputs, self.targets, self.keep_prob = build_inputs(
            batch_size, num_steps, input_size, output_size)

        # Build the LSTM cell
        cell, self.initial_state = build_lstm(lstm_size, num_layers,
                                              batch_size, self.keep_prob)

        # Run each sequence step through the RNN and collect the outputs
        outputs, state = tf.nn.dynamic_rnn(
            cell, inputs=self.inputs, initial_state=self.initial_state)
        self.final_state = state

        # Get softmax predictions and logits
        self.prediction = build_output(outputs[:, -1], lstm_size, output_size)

        # Loss and optimizer (with gradient clipping)
        self.loss = build_loss(self.prediction, self.targets)
        self.optimizer = build_optimizer(self.loss, learning_rate, grad_clip)

# %% [markdown]
# ## 超参数

# %%
batch_size = batch_size  # Sequences per batch
num_steps = TIME_STEP  # Number of sequence steps per batch
lstm_size = 50  # Size of hidden layers in LSTMs
num_layers = 3  # Number of LSTM layers
learning_rate = 0.0001  # Learning rate
keep_prob = 1  # Dropout keep probability
epochs = 50
# Save every N iterations
save_every_n = 200

# %% [markdown]
# ## 建立模型

# %%
model = SL_RNN(
    batch_size=batch_size,
    num_steps=num_steps,
    lstm_size=lstm_size,
    num_layers=num_layers,
    learning_rate=learning_rate,
    input_size=INPUT_SIZE,
    output_size=1
)

saver = tf.train.Saver()

# %% [markdown]
# ## 开始训练

# %%
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())

    # Use the line below to load a checkpoint and resume training
    #saver.restore(sess, 'checkpoints/______.ckpt')
    counter = 0
    loss = []
    for e in range(epochs):
        # Train network
        
        new_state = sess.run(model.initial_state)
        
        for x, y in get_batches(x_list, y_list, batch_size=batch_size):
            counter += 1
            start = time.time()
            feed = {
                model.inputs: x,
                model.targets: y,
                model.keep_prob: keep_prob,
                model.initial_state: new_state
            }
            batch_loss, new_state, _ = sess.run(
                [model.loss, model.final_state, model.optimizer],
                feed_dict=feed)
            
            loss.append(batch_loss)
            end = time.time()
            print('Epoch: {}/{}... '.format(e + 1, epochs), 
                  'Training Step: {}... '.format(counter),
                  'Training loss: {:.4f}... '.format(batch_loss),
                  '{:.4f} sec/batch'.format((end - start)))
            if (counter % save_every_n == 0):
                saver.save(sess, "checkpoints/i{}_l{}.ckpt".format(
                    counter, lstm_size))

    saver.save(sess, "checkpoints/i{}_l{}.ckpt".format(counter, lstm_size))
# Out:
# Epoch: 1/50...  Training Step: 1...  Training loss: 0.8490...  1.8439 sec/batch
# Epoch: 1/50...  Training Step: 2...  Training loss: 0.6879...  0.0322 sec/batch
# Epoch: 1/50...  Training Step: 3...  Training loss: 0.6004...  0.0315 sec/batch
# Epoch: 1/50...  Training Step: 4...  Training loss: 0.5616...  0.0307 sec/batch
# Epoch: 1/50...  Training Step: 5...  Training loss: 0.7350...  0.0307 sec/batch
# Epoch: 1/50...  Training Step: 6...  Training loss: 0.7075...  0.0297 sec/batch
# Epoch: 1/50...  Training Step: 7...  Training loss: 0.5751...  0.0296 sec/batch
# Epoch: 1/50...  Training Step: 8...  Training loss: 0.5383...  0.0366 sec/batch
# Epoch: 1/50...  Training Step: 9...  Training loss: 0.6213...  0.0418 sec/batch
# Epoch: 1/50...  Training Step: 10...  Training loss: 0.7097...  0.0400 sec/batch
# Epoch: 1/50...  Training Step: 11...  Training loss: 0.5760...  0.0307 sec/batch
# Epoch: 1/50...  Training Step: 12...  Training loss: 0.5228...  0.0302 sec/batch
# ...

# %% [markdown]
# ## 训练损失曲线

# %%
plt.plot(loss)

# %% [markdown]
# ## 模型验证

# %%
preds_ls=[]

# %%
checkpoint = tf.train.latest_checkpoint('checkpoints')

# %%
checkpoint
# Out:
# 'checkpoints/i8600_l50.ckpt'

# %%
checkpoint = tf.train.latest_checkpoint('checkpoints')
with tf.Session() as sess:
    saver.restore(sess, checkpoint)
    new_state = sess.run(model.initial_state)
    for x, y in get_batches(x_list, y_list, batch_size=batch_size):
        feed = {model.inputs: x,
                model.keep_prob: 1.,
                model.initial_state: new_state}
        preds, new_state = sess.run([model.prediction, model.final_state], 
                                     feed_dict=feed)
        new_state = sess.run(model.initial_state)
        preds_ls.append(preds)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/i8600_l50.ckpt

# %%
preds_ls[]
# Out:
# array([[ 0.85572058],
#        [ 0.85812509],
#        [ 0.85798997],
#        [ 0.85836202],
#        [ 0.85605544],
#        [ 0.85550779],
#        [ 0.85663867],
#        [ 0.85697389],
#        [ 0.85649103],
#        [ 0.85642105],
#        [ 0.85657424],
#        [ 0.85672265],
#        [ 0.85556859],
#        [ 0.85487634],
#        [ 0.85444498],
#        [ 0.84774303],
#        [ 0.84876865],
#        [ 0.84575695],
#        [ 0.85388023],
#        [ 0.84483266],
#        [ 0.84386641],
#        [ 0.85282302],
#        [ 0.84992135],
#        [ 0.84402734],
#        [ 0.83752096],
#        [ 0.20637231],
#        [ 0.06396203],
#        [ 0.57737786],
#        [ 0.39381769],
#        [ 0.59327042],
#        [ 0.74700844],
#        [ 0.69942808],
#        [ 0.92801952],
#        [ 0.86469245],
#        [ 0.85095316],
#        [ 0.85608333],
#        [ 0.85632145],
#        [ 0.85564959],
#        [ 0.85592109],
#        [ 0.85884476],
#        [ 0.85773635],
# ...

# %%
root_result=[]
for i in preds_ls:
    for j in i:
        root_result.append(j[0])
root_result
# Out:
# [0.812612,
#  0.85075265,
#  0.85657406,
#  0.85728461,
#  0.85776716,
#  0.85941315,
#  0.85764545,
#  0.85979736,
#  0.85909653,
#  0.85453826,
#  0.85478163,
#  0.8570286,
#  0.85575569,
#  0.85363227,
#  0.85664368,
#  0.8550877,
#  0.85529417,
#  0.85502136,
#  0.92006475,
#  0.93798417,
#  0.91282374,
#  0.85147536,
#  0.85595179,
#  0.85532629,
#  0.85459524,
#  0.85329926,
#  0.8632347,
#  0.93653595,
#  0.84174883,
#  0.81896085,
#  -0.12538646,
#  -0.77304214,
#  0.85377175,
#  0.80176485,
#  0.88175482,
#  0.87376451,
#  0.85520536,
#  0.85286123,
#  0.85575908,
#  0.85730696,
#  0.85838962,
#  0.85584807,
#  0.85643059,
#  0.85755455,
#  0.85905945,
#  0.85793746,
#  0.85804665,
#  0.85610586,
#  0.85784674,
#  0.85667717,
#  0.85598582,
#  0.8548246,
#  0.85370779,
#  0.84941977,
#  0.8463366,
#  0.85308987,
#  0.85471135,
#  0.85395318,
#  0.85325611,
#  0.85467619,
#  0.85622698,
#  0.85407442,
#  0.8503167,
#  0.84919763,
#  0.83501744,
#  0.81412083,
#  0.68842763,
# ...

# %%
(train_num-TIME_STEP+1)
# Out:
# 17241

# %%
result=[0]*(train_num-TIME_STEP+1)
index_1=index_2=0
bias=0
for bias in range(TIME_STEP):
    while((bias+index_1)<(train_num-TIME_STEP+1)):
        result[bias+index_1]=root_result[index_2]
        print(bias+index_1,index_2)
        index_2=index_2+1
        index_1=index_1+TIME_STEP
        if(index_2>(len(root_result)-1)):
            break
    index_1=0
result
# Out:
# 0 0
# 40 1
# 80 2
# 120 3
# 160 4
# 200 5
# 240 6
# 280 7
# 320 8
# 360 9
# 400 10
# 440 11
# 480 12
# 520 13
# 560 14
# 600 15
# 640 16
# 680 17
# 720 18
# 760 19
# 800 20
# 840 21
# 880 22
# 920 23
# 960 24
# 1000 25
# 1040 26
# 1080 27
# 1120 28
# 1160 29
# 1200 30
# 1240 31
# 1280 32
# 1320 33
# 1360 34
# 1400 35
# 1440 36
# 1480 37
# 1520 38
# 1560 39
# 1600 40
# 1640 41
# 1680 42
# 1720 43
# 1760 44
# 1800 45
# 1840 46
# 1880 47
# 1920 48
# 1960 49
# 2000 50
# 2040 51
# 2080 52
# 2120 53
# 2160 54
# 2200 55
# 2240 56
# 2280 57
# 2320 58
# 2360 59
# 2400 60
# 2440 61
# 2480 62
# 2520 63
# 2560 64
# 2600 65
# 2640 66
# 2680 67
# 2720 68
# 2760 69
# 2800 70
# 2840 71
# 2880 72
# 2920 73
# 2960 74
# 3000 75
# 3040 76
# 3080 77
# 3120 78
# 3160 79
# 3200 80
# 3240 81
# 3280 82
# 3320 83
# 3360 84
# 3400 85
# 3440 86
# 3480 87
# 3520 88
# 3560 89
# 3600 90
# 3640 91
# 3680 92
# 3720 93
# 3760 94
# 3800 95
# 3840 96
# 3880 97
# 3920 98
# 3960 99
# 4000 100
# 4040 101
# 4080 102
# ...

# %%
len(result)
# Out:
# 17241

# %%
test_pd=rate_pd.iloc[:train_num,:]

# %%
prd_rate=test_pd.drop("Unnamed: 0",axis=1)

# %%
prd_rate["prediction"]=0

# %%
prd_rate
# Out:
#                       time  hit_reach_rate  hit_cnt  prediction
# 0      2018-01-07 00:00:00        0.964348   2974.0           0
# 1      2018-01-07 00:01:00        0.970640   3211.0           0
# 2      2018-01-07 00:02:00        0.974182   2948.0           0
# 3      2018-01-07 00:03:00        0.980877   2987.0           0
# 4      2018-01-07 00:04:00        0.981185   3148.0           0
# 5      2018-01-07 00:05:00        0.978271   3089.0           0
# 6      2018-01-07 00:06:00        0.972449   2840.0           0
# 7      2018-01-07 00:07:00        0.972894   2879.0           0
# 8      2018-01-07 00:08:00        0.978487   2801.0           0
# 9      2018-01-07 00:09:00        0.974852   2833.0           0
# 10     2018-01-07 00:10:00        0.968931   2866.0           0
# 11     2018-01-07 00:11:00        0.964422   2901.0           0
# 12     2018-01-07 00:12:00        0.978116   2697.0           0
# 13     2018-01-07 00:13:00        0.970578   2895.0           0
# ...

# %%
prd_rate.loc[len(prd_rate)-len(result):,"prediction"]=result

# %%
prd_rate.columns
# Out:
# Index(['time', 'hit_reach_rate', 'hit_cnt', 'prediction'], dtype='object')

# %%
feature_plot(prd_rate,"prediction")
feature_plot(prd_rate,"hit_reach_rate")

# %%
((prd_rate["prediction"]*100-prd_rate["hit_reach_rate"])[4000:]).mean()
